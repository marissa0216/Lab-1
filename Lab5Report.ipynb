# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN = 326.5
AUD1_MEAN = 965
VIS1_STD = 30.31
AUD1_STD = 160.33

# %% [markdown]
# # Purpose
# To measure auditory and visual reaction in ms.
#
# # Procedure
# Followed the link on the assigment for lab 5. For the visual activity I had to click every time I saw the screen turned green. For the auditory I had to click the screen every time I hear the noise. I repeated it 10 times each. The links were human bench mark and play back auditory.
#
# # Results

# %%
# build a bar plot
plt.bar(['Person 1 Visual', 'Person 1 Auditory'],[VIS1_MEAN, AUD1_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')

# %% [markdown]
# # Discussion
# This was an interesting activity to measure the visual and auditory reaction tine. Results were interesting.
#
# # Conclusion
# In conclusion after this activity the t test score was significally different with the score of less than 0.05.
